# %%
import shutil
import os

repo_name = "bert-attention-entropy"

if os.path.exists(repo_name):
    shutil.rmtree(repo_name)
    print("Old repo deleted.")

print("Ready to clone fresh copy.")
# Out:
# Old repo deleted.
# Ready to clone fresh copy.

# %%
# !git clone https://github.com/egebasaran99/bert-attention-entropy.git
# %cd bert-attention-entropy
# Out:
# Cloning into 'bert-attention-entropy'...
# remote: Enumerating objects: 127, done.
# remote: Counting objects: 100% (127/127), done.
# remote: Compressing objects: 100% (96/96), done.
# remote: Total 127 (delta 52), reused 70 (delta 16), pack-reused 0 (from 0)
# Receiving objects: 100% (127/127), 525.10 KiB | 3.26 MiB/s, done.
# Resolving deltas: 100% (52/52), done.
# /content/bert-attention-entropy

# %%
# !pip install -r requirements.txt
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 54.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.6/137.6 kB 1.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 108.5 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.0/9.0 MB 81.7 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 9.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 18.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.1/183.1 kB 14.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 865.0/865.0 kB 19.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 46.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 65.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 82.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
# ...

# %%
# !python src/data_prep.py --n 2000 --min_tokens 10 --max_tokens 25
# Out:
# ...
# Collected 2000 sentences.
# Saved to data/raw/sentences.txt
#
# --- Validation Report ---
# Total sentences : 2000
# Avg token count : 15.5
# Min token count : 10
# Max token count : 25
#
# Sample sentences:
#   [12 tokens] that loves its characters and communicates something rather beautiful about human nature
#   [10 tokens] on the worst revenge-of-the-nerds clichés the filmmakers could dredge up
#   [10 tokens] that 's far too tragic to merit such superficial treatment
#   [25 tokens] demonstrates that the director of such hollywood blockbusters as patriot games can still turn out a small , personal film with an emotional wallop .
#   [12 tokens] are more deeply thought through than in most ` right-thinking ' films
# -------------------------

# %%
# !python src/corrupt.py
# Out:
# Loaded 2000 sentences from data/raw/sentences.txt
# Applying corruptions...
#   Processing sentence 0/2000...
#   Processing sentence 100/2000...
#   Processing sentence 200/2000...
#   [WARNING] No noun phrases found, returning original: 'is moody , oozing , chilling and heart-warming all at once'
#   Processing sentence 300/2000...
#   [WARNING] No noun phrases found, returning original: 'muddled , simplistic and more than a little pretentious .'
#   Processing sentence 400/2000...
#   [WARNING] No noun phrases found, returning original: 'been written so well , that even a simple `` goddammit'
#   [WARNING] No noun phrases found, returning original: 'worked five years ago but has since lost its fizz'
#   Processing sentence 500/2000...
#   [WARNING] No noun phrases found, returning original: 'pretends to be passionate and truthful but is really frustratingly timid and soggy'
# ...

# %%
# !python src/inference.py --output_path results/entropy_results_sst2_2000.json
# Out:
# Using device: cpu
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py:949: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
#
# Processing condition: original
#   Loaded 2000 sentences.
#   original: 100% 2000/2000 [04:25<00:00,  7.54it/s]
#   Saved progress to results/entropy_results_sst2_2000.json
#
# Processing condition: np_shuffled
#   Loaded 2000 sentences.
#   np_shuffled: 100% 2000/2000 [04:24<00:00,  7.56it/s]
#   Saved progress to results/entropy_results_sst2_2000.json
#
# Processing condition: full_shuffled
#   Loaded 2000 sentences.
#   full_shuffled: 100% 2000/2000 [04:23<00:00,  7.58it/s]
#   Saved progress to results/entropy_results_sst2_2000.json
#
# All conditions complete. Final results at: results/entropy_results_sst2_2000.json
#
# --- Inference Summary ---
# ...

# %%
# !python analysis/plot_entropy.py --results_path results/entropy_results_sst2_2000.json --output_dir results/plots_sst2_2000
# Out:
# Loading results from: results/entropy_results_sst2_2000.json
#   [original] 2000 sentences x 12 layers loaded.
#   [np_shuffled] 2000 sentences x 12 layers loaded.
#   [full_shuffled] 2000 sentences x 12 layers loaded.
#
# Generating plots...
# Saved: results/plots_sst2_2000/plot1_mean_entropy.png
# Saved: results/plots_sst2_2000/plot2_entropy_delta.png
# Saved: results/plots_sst2_2000/plot3_boxplots.png
# Saved: results/plots_sst2_2000/plot4_delta_heatmap.png
#
# Running significance tests...
#
# --- Paired t-test results (corruption vs original) ---
# Layer   NP-shuffled           Full-sentence shuffle
# ----------------------------------------------------
# 1       p=0.7607               p=0.0000 ***
# 2       p=0.0000 ***           p=0.0000 ***
# 3       p=0.0000 ***           p=0.0000 ***
# 4       p=0.0000 ***           p=0.0059 **
# 5       p=0.0000 ***           p=0.0000 ***
# 6       p=0.0000 ***           p=0.0000 ***
# 7       p=0.0000 ***           p=0.0000 ***
# ...
